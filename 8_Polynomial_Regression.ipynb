# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# Data
X = np.array([1,2,3,4,5,6,7,8]).reshape(-1,1)
y = np.array([25000,27000,32000,40000,60000,90000,140000,200000])

# %%
plt.scatter(X,y)

# %%
# Linear Regression (baseline)
lin_model = LinearRegression()
lin_model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Polynomial Regression (degree=3)
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# %%
poly_model = LinearRegression()
poly_model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Predictions
y_pred_lin = lin_model.predict(X)
y_pred_poly = poly_model.predict(X_poly)

# %%
y_pred_lin
# Out:
# array([ -5916.66666667,  17702.38095238,  41321.42857143,  64940.47619048,
#         88559.52380952, 112178.57142857, 135797.61904762, 159416.66666667])

# %%
y_pred_poly
# Out:
# array([ 25439.39393939,  26590.90909091,  30822.51082251,  41073.59307359,
#         60283.54978355,  91391.77489177, 137337.66233766, 201060.60606061])
